# %%
# %run -i run_ml_pipeline.py
# Out:
# Loading data...
# Processed 260 files, total 9198 slices
# Experiment started.
# Training epoch 0...
#
# Epoch: 0 Train loss: 1.0797497034072876, 0.3% complete
# ..........
# Epoch: 0 Train loss: 0.31081560254096985, 3.2% complete
# ..........
# Epoch: 0 Train loss: 0.0880027785897255, 6.1% complete
# ..........
# Epoch: 0 Train loss: 0.07648688554763794, 9.0% complete
# ..........
# Epoch: 0 Train loss: 0.062092848122119904, 11.8% complete
# ..........
# Epoch: 0 Train loss: 0.07036229968070984, 14.7% complete
# ..........
# Epoch: 0 Train loss: 0.05232446268200874, 17.6% complete
# ..........
# Epoch: 0 Train loss: 0.06863465160131454, 20.5% complete
# ..........
# Epoch: 0 Train loss: 0.0583946667611599, 23.4% complete
# ..........
# Epoch: 0 Train loss: 0.041854940354824066, 26.3% complete
# ..........
# Epoch: 0 Train loss: 0.03861077502369881, 29.2% complete
# ..........
# Epoch: 0 Train loss: 0.041478369385004044, 32.1% complete
# ..........
# ...
